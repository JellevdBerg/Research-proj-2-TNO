# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
data_path = "../Data/docs/4.papyrus_present_genes&compounds.csv"
df = pd.read_csv(data_path)
df
# Out:
#        Symbol                          source  \
# 0        EGFR  ChEMBL34;Sharma2016;Sharma2016
# 1        EGFR                      Sharma2016
# 2        EGFR                      Sharma2016
# 3        EGFR                        ChEMBL34
# 4        EGFR                      Sharma2016
# ...       ...                             ...
# 288238  AMPD1                        ChEMBL34
# 288239  TRAF6                        ChEMBL34
# 288240   FRS2                        ChEMBL34
# 288241  CERS1                        ChEMBL34
# 288242   VAT1                        ChEMBL34
#
#                                                       CID Uniprot  \
# 0       ChEMBL:CHEMBL175513;Sharma2016.compound.427704...  P00533
# 1                            Sharma2016.compound.10064954  P00533
# 2                             Sharma2016.compound.4486432  P00533
# 3                                    ChEMBL:CHEMBL2048906  P00533
# 4                             Sharma2016.compound.4358384  P00533
# ...                                                   ...     ...
# 288238                                ChEMBL:CHEMBL346040  P23109
# 288239                               ChEMBL:CHEMBL3590514  Q9Y4K3
# 288240                               ChEMBL:CHEMBL3964954  Q8WU20
# 288241                               ChEMBL:CHEMBL5268405  P27544
# 288242                               ChEMBL:CHEMBL4214264  Q99536
#
#                            InChIKey  \
# 0       AAAAZQPHATYWOK-UHFFFAOYSA-N
# 1       AAEPFBULPJOZCS-UHFFFAOYSA-N
# 2       AAFHSECTTHOVFV-UHFFFAOYSA-N
# 3       AAGKMGNYUYCEPD-UHFFFAOYSA-N
# 4       AAHKGRWRYBCWDL-UHFFFAOYSA-N
# ...                             ...
# 288238  YPFKFJNLCPXDDR-UHFFFAOYSA-N
# 288239  ZISVYNIBYVBIJV-UHFFFAOYSA-N
# 288240  ZJFCBQXPTQSTCZ-UHFFFAOYSA-N
# 288241  ZQQHXJCIFGMUPY-UHFFFAOYSA-N
# 288242  ZRPZPNYZFSJUPA-UHFFFAOYSA-N
#
#                                                    SMILES  pchembl_value_Mean
# 0       CCOc1cc2ncc(C#N)c(Nc3ccc(OCc4nc5ccccc5s4)c(Cl)...               6.506
# 1       C=CC(=O)Nc1cccc(-n2c(=O)cc(C)c3cnc(Nc4cn(C)nc4...               7.276
# 2       COc1cc(N2CCN(C)CC2)ccc1Nc1ncc2c(n1)N(c1cccc(N)...               5.528
# 3       CC(=O)NCCn1ccc2ncnc(Nc3ccc(Oc4cccc5sncc45)c(Cl...               8.540
# 4               CCOc1ccc(-c2nn(C3CCCC3)c3ncnc(N)c23)cc1OC               5.854
# ...                                                   ...                 ...
# 288238       O=C(O)c1cc(CCn2cnc3c2N=CNCC3O)c2c(c1Br)CCCC2               6.300
# 288239  COc1ccc(S(=O)(=O)NC(=O)c2ccc(NC(=O)Cn3c(=O)sc4...               4.460
# 288240  Cn1cc(-c2ccc3c(c2)ncn3-c2cc(NS(=O)(=O)C3CC3)cc...               7.103
# 288241            CC(N)(CO)CCc1ccc(OCc2ccc(Cl)c(Cl)c2)cc1               6.270
# 288242  C=CC(=O)N1CCN(c2ncnc3c(F)c(-c4c(O)cccc4F)c(Cl)...               5.345
#
# [288243 rows x 7 columns]

# %%
# filter df symbol
symbol = 'ACVR2B'
# 147702  COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(N...            5.367000
# 147703  C=c1c(C(=O)NCC(O)CN2CCOCC2)c(C)[nH]c1=Cc1c(O)[...            5.000000
# 147704  CCN(CCO)CCCOc1ccc2c(Nc3cc(CC(=O)Nc4cccc(F)c4)[...            5.000000
# 147705        CC1(C)CNc2cc(NC(=O)c3cccnc3NCc3ccncc3)ccc21            5.000000
# 147706  CCn1cc(-c2ccnc3[nH]c(-c4cccc(CN(C)C)c4)cc23)c(...            5.000000
# 147707      CNC(=O)c1ccccc1Sc1ccc2c(C=Cc3ccccn3)[nH]nc2c1            5.284000
# 147708          Oc1cccc(-c2nc(N3CCOCC3)c3oc4ncccc4c3n2)c1            5.000000
# 147709      COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1            5.000000
# 147710           CC1CCN(C(=O)CC#N)CC1N(C)c1ncnc2[nH]ccc12            5.000000
# 147711  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...            5.000000
# 147712  CC12OC(CC1(O)CO)n1c3ccccc3c3c4c(c5c6ccccc6n2c5...            5.420000
# 147713     O=c1ncn2nc(Sc3ccc(F)cc3F)ccc2c1-c1c(Cl)cccc1Cl            5.000000
# 147714  CSc1cccc(Nc2ncc3cc(-c4c(Cl)cccc4Cl)c(=O)n(C)c3...            8.041000
# 147715  CCOc1cc2ncc(C#N)c(Nc3ccc(F)c(Cl)c3)c2cc1NC(=O)...            5.000000
# 147716     COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN1CCOCC1            5.000000
# 147717  Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4nc(C...            5.000000
# 147718             Clc1ccc(Nc2nnc(Cc3ccncc3)c3ccccc23)cc1            5.000000
# 147719  CN(C)CC1CCn2cc(c3ccccc32)C2=C(C(=O)NC2=O)c2cn(...            5.000000
# 147720         O=C(c1ccc(C=Cc2[nH]nc3ccccc23)cc1)N1CCNCC1            6.161000
# 147721  CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc...            5.495000
# 147722  Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(C...            6.168167
# 147723  COC1C(N(C)C(=O)c2ccccc2)CC2OC1(C)n1c3ccccc3c3c...            5.000000

# %%
# make list of SMILES column in df_targeted
smiles_list = df_target['SMILES'].tolist()
smiles_list2 = df_suplement['SMILES'].tolist()
print('ACVR2B molecules:', len(smiles_list))
print('ACVR molecules:', len(smiles_list2))
# Out:
# ACVR2B molecules: 54
# ACVR molecules: 107

# %%
total_smiles = len(smiles_list)  # Total SMILES in the list

# Filter rows where SMILES column matches any in the list
filtered_df = df[df['SMILES'].isin(smiles_list)]

# Remove duplicate (SMILES, Symbol) pairs to ensure each SMILES is counted only once per Symbol
filtered_df = filtered_df.drop_duplicates(subset=['SMILES', 'Symbol'])

# Exclude 'ACVR2B' from the analysis
filtered_df = filtered_df[filtered_df['Symbol'] != 'ACVR2B']

# Count occurrences of each Symbol
symbol_counts = filtered_df['Symbol'].value_counts()

# Convert counts to percentage of total SMILES list
symbol_percentage = (symbol_counts / total_smiles) * 100

# Select the top 15 symbols with the highest percentage
top_15_symbols = symbol_percentage.head(15)

# Plot the bar chart
plt.figure(figsize=(6, 5))
top_15_symbols.plot(kind='bar', color='grey', edgecolor='black', width=0.8)

# Beautify the plot
plt.xlabel("Genes")
plt.ylabel("Percentage (%)")
plt.title("Percentage of ACVR2B compounds not specific to ACVR2B")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 100)
plt.savefig("../Results/images/ACVR2B_compounds_percentage.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
# count number of different inputs in source
source_counts = df_target['source'].value_counts()
print(source_counts)
# Out:
# source
# Christmann2016                            43
# ChEMBL34                                   7
# Christmann2016;ChEMBL34;Christmann2016     3
# ChEMBL34;Christmann2016                    1
# Name: count, dtype: int64

# %%
df_validation = df_target.copy()
df_validation['active'] = (df_validation['pchembl_value_Mean'] >= 5).astype(int)
df_validation
# Out:
#         Symbol                                  source  \
# 147670  ACVR2B                          Christmann2016
# 147671  ACVR2B                          Christmann2016
# 147672  ACVR2B  Christmann2016;ChEMBL34;Christmann2016
# 147673  ACVR2B                                ChEMBL34
# 147674  ACVR2B                          Christmann2016
# 147675  ACVR2B                          Christmann2016
# 147676  ACVR2B  Christmann2016;ChEMBL34;Christmann2016
# 147677  ACVR2B                          Christmann2016
# 147678  ACVR2B                          Christmann2016
# 147679  ACVR2B                          Christmann2016
# 147680  ACVR2B                          Christmann2016
# 147681  ACVR2B                          Christmann2016
# 147682  ACVR2B  Christmann2016;ChEMBL34;Christmann2016
# 147683  ACVR2B                                ChEMBL34
# 147684  ACVR2B                                ChEMBL34
# 147685  ACVR2B                 ChEMBL34;Christmann2016
# 147686  ACVR2B                                ChEMBL34
# 147687  ACVR2B                          Christmann2016
# 147688  ACVR2B                          Christmann2016
# 147689  ACVR2B                          Christmann2016
# 147690  ACVR2B                          Christmann2016
# 147691  ACVR2B                          Christmann2016
# 147692  ACVR2B                          Christmann2016
# 147693  ACVR2B                          Christmann2016
# 147694  ACVR2B                          Christmann2016
# 147695  ACVR2B                          Christmann2016
# 147696  ACVR2B                          Christmann2016
# 147697  ACVR2B                          Christmann2016
# 147698  ACVR2B                          Christmann2016
# 147699  ACVR2B                                ChEMBL34
# 147700  ACVR2B                          Christmann2016
# 147701  ACVR2B                          Christmann2016
# 147702  ACVR2B                          Christmann2016
# 147703  ACVR2B                          Christmann2016
# 147704  ACVR2B                          Christmann2016
# 147705  ACVR2B                          Christmann2016
# 147706  ACVR2B                                ChEMBL34
# 147707  ACVR2B                          Christmann2016
# 147708  ACVR2B                          Christmann2016
# 147709  ACVR2B                          Christmann2016
# 147710  ACVR2B                          Christmann2016
# 147711  ACVR2B                          Christmann2016
# 147712  ACVR2B                          Christmann2016
# 147713  ACVR2B                          Christmann2016
# 147714  ACVR2B                          Christmann2016
# 147715  ACVR2B                          Christmann2016
# 147716  ACVR2B                          Christmann2016
# 147722  Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(C...            6.168167
# 147723  COC1C(N(C)C(=O)c2ccccc2)CC2OC1(C)n1c3ccccc3c3c...            5.000000
#
#         active
# 147670       1
# 147671       1
# 147672       1
# 147673       1
# 147674       1
# 147675       1
# 147676       1
# 147677       1
# 147678       0
# 147679       1
# 147680       1
# 147681       1
# 147682       1
# 147683       1
# 147684       1
# 147685       1
# 147686       1
# 147687       1
# 147688       1
# 147689       1
# 147690       1
# 147691       1
# 147692       1
# 147693       1
# 147694       1
# 147695       1
# 147696       1
# 147697       1
# 147698       1
# 147699       1
# 147700       1
# 147701       1
# 147702       1
# 147703       1
# 147704       1
# 147705       1
# 147706       1
# 147707       1
# 147708       1
# 147709       1
# 147710       1
# 147711       1
# 147712       1
# 147713       1
# 147714       1
# 147715       1
# 147716       1
# 147717       1
# 147718       1
# 147719       1
# 147720       1
# 147721       1
# 147722       1
# 147723       1

# %%
# only keep rows where pchembl_value_Mean > 6
df_short = df_target[df_target['pchembl_value_Mean'] > 5]
df_short
# Out:
#         Symbol                                  source  \
# 147672  ACVR2B  Christmann2016;ChEMBL34;Christmann2016
# 147673  ACVR2B                                ChEMBL34
# 147676  ACVR2B  Christmann2016;ChEMBL34;Christmann2016
# 147682  ACVR2B  Christmann2016;ChEMBL34;Christmann2016
# 147683  ACVR2B                                ChEMBL34
# 147684  ACVR2B                                ChEMBL34
# 147685  ACVR2B                 ChEMBL34;Christmann2016
# 147686  ACVR2B                                ChEMBL34
# 147691  ACVR2B                          Christmann2016
# 147698  ACVR2B                          Christmann2016
# 147699  ACVR2B                                ChEMBL34
# 147701  ACVR2B                          Christmann2016
# 147702  ACVR2B                          Christmann2016
# 147707  ACVR2B                          Christmann2016
# 147712  ACVR2B                          Christmann2016
# 147714  ACVR2B                          Christmann2016
# 147720  ACVR2B                          Christmann2016
# 147721  ACVR2B                          Christmann2016
# 147722  ACVR2B                                ChEMBL34
#
#                                                       CID Uniprot  \
# 147672  Christmann2016.compound.18;ChEMBL:CHEMBL428690...  Q13705
# 147673                               ChEMBL:CHEMBL3823101  Q13705
# 147676  Christmann2016.compound.39;ChEMBL:CHEMBL477772...  Q13705
# 147682  Christmann2016.compound.1;ChEMBL:CHEMBL388978;...  Q13705
# 147683                               ChEMBL:CHEMBL4283638  Q13705
# 147684                               ChEMBL:CHEMBL2041933  Q13705
# 147685     ChEMBL:CHEMBL191003;Christmann2016.compound.58  Q13705
# 147686                               ChEMBL:CHEMBL3991933  Q13705
# 147691                          Christmann2016.compound.5  Q13705
# 147698                         Christmann2016.compound.24  Q13705
# 147699                                ChEMBL:CHEMBL217092  Q13705
# 147701     Christmann2016.compound.45;ChEMBL:CHEMBL278041  Q13705
# 147702                         Christmann2016.compound.10  Q13705
# 147707                         Christmann2016.compound.73  Q13705
# 147712                          Christmann2016.compound.2  Q13705
# 147714                         Christmann2016.compound.67  Q13705
# 147720    Christmann2016.compound.20;ChEMBL:CHEMBL1908397  Q13705
# 147714  CSc1cccc(Nc2ncc3cc(-c4c(Cl)cccc4Cl)c(=O)n(C)c3...            8.041000
# 147720         O=C(c1ccc(C=Cc2[nH]nc3ccccc23)cc1)N1CCNCC1            6.161000
# 147721  CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc...            5.495000
# 147722  Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(C...            6.168167

# %%
# Create the violin plot with a custom color palette and save it
plt.figure(figsize=(6, 5))

# Set background color
plt.gcf().set_facecolor('white')  # Set figure background color
sns.set_theme(style="ticks")  # Set seaborn style for the axes background

sns.violinplot(x='Symbol', y='pchembl_value_Mean', data=df_target, color='pink')  # Using Set2 palette

# Beautify the plot
plt.xlabel("")
plt.ylabel("pChEMBL Value (Mean)")
plt.title("Violin Plot of Acitivy values for ACVR2B compounds")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.savefig("../Results/images/violin_data_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Load the data
data_path = "../Data/docs/4.papyrus_present_genes&compounds.csv"
df = pd.read_csv(data_path)

# List of symbols to filter for
symbols_to_filter = ['ACVR1', 'ACVR2B', 'ACVR1B', 'ACVR2A']  # Replace with your list of symbols

# Filter the dataframe based on the list of symbols
df_filtered = df[df['Symbol'].isin(symbols_to_filter)].dropna()
#df_filtered = df_filtered[df_filtered['source'].isin(sources_to_remove)]

# Create the violin plot with a custom color palette
plt.figure(figsize=(12, 5))

# Set background color
plt.gcf().set_facecolor('white')  # Set figure background color
sns.set_theme(style="ticks")  # Set seaborn style for the axes background

sns.violinplot(x='Symbol', y='pchembl_value_Mean', data=df_filtered, inner='box', color='pink')  # Using Set2 palette

# Beautify the plot
plt.xlabel("Gene Symbol")
plt.ylabel("pChEMBL Value (Mean)")
plt.title("Violin Plot of pChEMBL Mean Values per Gene")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# Generate RDKit molecule objects from the SMILES column
molecules = [Chem.MolFromSmiles(smiles) for smiles in df_short['SMILES']]

# Format the pchembl_value_Mean column to 3 decimal places
df_short['pchembl_value_Mean'] = df_short['pchembl_value_Mean'].round(3)

# Update legends with formatted values
legends = df_short['pchembl_value_Mean'].astype(str).tolist()

# Regenerate the grid image with updated legends
img = Draw.MolsToGridImage(molecules, molsPerRow=4, subImgSize=(400, 400), legends=legends)

with open("../Results/images/pharmacophore molecules.png", "wb") as png:
    png.write(img.data)
# Display the image
img
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 from rdkit.Chem import Draw
#       4 # Generate RDKit molecule objects from the SMILES column
# ----> 5 molecules = [Chem.MolFromSmiles(smiles) for smiles in df_short['SMILES']]
#       7 # Format the pchembl_value_Mean column to 3 decimal places
#       8 df_short['pchembl_value_Mean'] = df_short['pchembl_value_Mean'].round(3)
#
# NameError: name 'df_short' is not defined

# %%
# save df_target to CSV file
df_short.to_csv("../Data/docs/5.compounds for vina.csv", index=False)

# save only the SMILES column to CSV file
df_smiles = df_short[['SMILES']]
df_smiles.to_csv("../Data/docs/6.compounds for vina smiles.csv", index=False)
